# %% [markdown]
# # Eksperymenty: Strojenie Hiperparametrów Modeli
#
# W tym notatniku przeprowadzimy eksperymenty mające na celu znalezienie najlepszych hiperparametrów dla modeli TF-IDF i Doc2Vec.
#
# ## Metodyka
#
# 1.  **Złoty Zbiór Zapytań**: Definiujemy zestaw zapytań i oczekiwanych dokumentów.
# 2.  **Grid Search**: Iterujemy po różnych kombinacjach parametrów dla każdego modelu.
# 3.  **Ocena**: Dla każdej kombinacji obliczamy średnią rangę i wynik podobieństwa dla oczekiwanych dokumentów.
# 4.  **Wnioski**: Wybieramy najlepszy zestaw parametrów.

# %%
import pandas as pd
import itertools
from tqdm.std import tqdm as tqdm
import sys

from service.document_service import DocumentService
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from gensim.models.doc2vec import Doc2Vec, TaggedDocument

# Ustawienia i ładowanie danych
sys.path.append('.')
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', 1000)
pd.set_option('display.max_colwidth', None)
doc_service = DocumentService()
documents = doc_service.load_documents()
print(f"Załadowano {len(documents)} dokumentów.")
# Out:
# Załadowano 1000 dokumentów.

# %% [markdown]
# ## 1. Zdefiniowanie Złotego Zbioru Zapytań
#
# **Wypełnij poniższą listę.** Wpisz zapytania i nazwę pliku, który Twoim zdaniem najlepiej na nie odpowiada.

# %%
GOLDEN_SET = {
    "Violence on board during US flight": "kaggle_1.txt",
    "Statistics regarding new virus vaccination fall campaign": "kaggle_0.txt",
    "Supreme Court spouse talks to Capitol riot investigators": "kaggle_14.txt",
    "Rapper gives financial support to Bronx education institution": "kaggle_50.txt",
    "Lawyers argue for life imprisonment for mass murderer": "kaggle_188.txt",
    "New anchor takes over prime time slot on cable news": "kaggle_450.txt",
    "Movie director discusses complex adult film industry character": "kaggle_667.txt",
    "Fatal accident involving college sports team students": "kaggle_999.txt"
}

# %% [markdown]
# ## 2. Eksperymenty z TF-IDF

# %%
def run_tfidf_experiment(docs, golden_set, vectorizer_params):
    doc_contents = [d.content for d in docs]
    doc_names = [d.name for d in docs]
    
    vectorizer = TfidfVectorizer(**vectorizer_params)
    tfidf_matrix = vectorizer.fit_transform(doc_contents)
    
    results = {}
    for query, expected_doc_name in golden_set.items():
        query_processed = DocumentService.preprocess_text(query)
        query_vector = vectorizer.transform([query_processed])
        
        sims = cosine_similarity(query_vector, tfidf_matrix).flatten()
        
        # Znajdź wynik dla oczekiwanego dokumentu
        try:
            expected_doc_idx = doc_names.index(expected_doc_name)
            score = sims[expected_doc_idx]
            
            # Znajdź rangę
            sorted_indices = sims.argsort()[::-1]
            rank = list(sorted_indices).index(expected_doc_idx) + 1
            
            results[query] = {'rank': rank, 'score': score}
        except ValueError:
            results[query] = {'rank': -1, 'score': -1}
            
    return results

# Siatka parametrów do przetestowania dla TF-IDF
tfidf_param_grid = {
    'ngram_range': [(1, 1), (1, 2), (2, 2)],
    'min_df': [1, 2, 3, 5],
    'max_df': [0.8, 0.9],
    'sublinear_tf': [True, False],
    'norm': ['l2']
}



tfidf_results = []
params_list = list(itertools.product(*tfidf_param_grid.values()))

for params in tqdm(params_list, desc="TF-IDF Experiments"):
    current_params = dict(zip(tfidf_param_grid.keys(), params))
    
    # Przebieg eksperymentu dla wszystkich zapytań z GOLDEN_SET
    query_results = run_tfidf_experiment(documents, GOLDEN_SET, current_params)
    
    ranks = [res['rank'] for res in query_results.values() if res['rank'] != -1]
    scores = [res['score'] for res in query_results.values() if res['score'] != -1]
    
    if ranks:
        avg_rank = sum(ranks) / len(ranks)
        avg_score = sum(scores) / len(scores)
        result_entry = {**current_params, 'avg_rank': avg_rank, 'avg_score': avg_score, 'all_results': query_results}
        tfidf_results.append(result_entry)

tfidf_df = pd.DataFrame(tfidf_results)
tfidf_df.sort_values(by=['avg_rank', 'avg_score'], ascending=[True, False], inplace=True)

print("Najlepsze parametry dla TF-IDF")
display(tfidf_df.head(100))
# Out:
# TF-IDF Experiments: 100%|██████████| 48/48 [00:00<00:00, 51.25it/s]
# Najlepsze parametry dla TF-IDF
#    ngram_range  min_df  max_df  sublinear_tf norm  avg_rank  avg_score                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   all_results
# 28      (1, 2)       5     0.8          True   l2   141.125   0.179287      {'Violence on board during US flight': {'rank': 9, 'score': 0.21996089551565737}, 'Statistics regarding new virus vaccination fall campaign': {'rank': 11, 'score': 0.18954643879981192}, 'Supreme Court spouse talks to Capitol riot investigators': {'rank': 28, 'score': 0.19314707622584368}, 'Rapper gives financial support to Bronx education institution': {'rank': 5, 'score': 0.25862309051365917}, 'Lawyers argue for life imprisonment for mass murderer': {'rank': 59, 'score': 0.08955198808071897}, 'New anchor takes over prime time slot on cable news': {'rank': 53, 'score': 0.11167377483939141}, 'Movie director discusses complex adult film industry character': {'rank': 961, 'score': 0.0}, 'Fatal accident involving college sports team students': {'rank': 3, 'score': 0.37179015473094784}}
# 30      (1, 2)       5     0.9          True   l2   141.125   0.179287      {'Violence on board during US flight': {'rank': 9, 'score': 0.21996089551565737}, 'Statistics regarding new virus vaccination fall campaign': {'rank': 11, 'score': 0.18954643879981192}, 'Supreme Court spouse talks to Capitol riot investigators': {'rank': 28, 'score': 0.19314707622584368}, 'Rapper gives financial support to Bronx education institution': {'rank': 5, 'score': 0.25862309051365917}, 'Lawyers argue for life imprisonment for mass murderer': {'rank': 59, 'score': 0.08955198808071897}, 'New anchor takes over prime time slot on cable news': {'rank': 53, 'score': 0.11167377483939141}, 'Movie director discusses complex adult film industry character': {'rank': 961, 'score': 0.0}, 'Fatal accident involving college sports team students': {'rank': 3, 'score': 0.37179015473094784}}
# 29      (1, 2)       5     0.8         False   l2   141.125   0.174523         {'Violence on board during US flight': {'rank': 9, 'score': 0.21996089551565737}, 'Statistics regarding new virus vaccination fall campaign': {'rank': 11, 'score': 0.185013592740212}, 'Supreme Court spouse talks to Capitol riot investigators': {'rank': 32, 'score': 0.17722173653810155}, 'Rapper gives financial support to Bronx education institution': {'rank': 5, 'score': 0.2455921702276022}, 'Lawyers argue for life imprisonment for mass murderer': {'rank': 58, 'score': 0.08493210772175865}, 'New anchor takes over prime time slot on cable news': {'rank': 50, 'score': 0.11167377483939141}, 'Movie director discusses complex adult film industry character': {'rank': 961, 'score': 0.0}, 'Fatal accident involving college sports team students': {'rank': 3, 'score': 0.37179015473094784}}
# 31      (1, 2)       5     0.9         False   l2   141.125   0.174523         {'Violence on board during US flight': {'rank': 9, 'score': 0.21996089551565737}, 'Statistics regarding new virus vaccination fall campaign': {'rank': 11, 'score': 0.185013592740212}, 'Supreme Court spouse talks to Capitol riot investigators': {'rank': 32, 'score': 0.17722173653810155}, 'Rapper gives financial support to Bronx education institution': {'rank': 5, 'score': 0.2455921702276022}, 'Lawyers argue for life imprisonment for mass murderer': {'rank': 58, 'score': 0.08493210772175865}, 'New anchor takes over prime time slot on cable news': {'rank': 50, 'score': 0.11167377483939141}, 'Movie director discusses complex adult film industry character': {'rank': 961, 'score': 0.0}, 'Fatal accident involving college sports team students': {'rank': 3, 'score': 0.37179015473094784}}
# 21      (1, 2)       2     0.8         False   l2   141.500   0.115261        {'Violence on board during US flight': {'rank': 9, 'score': 0.13549555621392861}, 'Statistics regarding new virus vaccination fall campaign': {'rank': 12, 'score': 0.11422741238953942}, 'Supreme Court spouse talks to Capitol riot investigators': {'rank': 37, 'score': 0.09805660853936517}, 'Rapper gives financial support to Bronx education institution': {'rank': 6, 'score': 0.1521451850606366}, 'Lawyers argue for life imprisonment for mass murderer': {'rank': 46, 'score': 0.07966297015364651}, 'New anchor takes over prime time slot on cable news': {'rank': 61, 'score': 0.05746337486394994}, 'Movie director discusses complex adult film industry character': {'rank': 960, 'score': 0.0}, 'Fatal accident involving college sports team students': {'rank': 1, 'score': 0.2850402079901924}}
# 23      (1, 2)       2     0.9         False   l2   141.500   0.115261        {'Violence on board during US flight': {'rank': 9, 'score': 0.13549555621392861}, 'Statistics regarding new virus vaccination fall campaign': {'rank': 12, 'score': 0.11422741238953942}, 'Supreme Court spouse talks to Capitol riot investigators': {'rank': 37, 'score': 0.09805660853936517}, 'Rapper gives financial support to Bronx education institution': {'rank': 6, 'score': 0.1521451850606366}, 'Lawyers argue for life imprisonment for mass murderer': {'rank': 46, 'score': 0.07966297015364651}, 'New anchor takes over prime time slot on cable news': {'rank': 61, 'score': 0.05746337486394994}, 'Movie director discusses complex adult film industry character': {'rank': 960, 'score': 0.0}, 'Fatal accident involving college sports team students': {'rank': 1, 'score': 0.2850402079901924}}
# 20      (1, 2)       2     0.8          True   l2   141.750   0.118537      {'Violence on board during US flight': {'rank': 10, 'score': 0.13549555621392861}, 'Statistics regarding new virus vaccination fall campaign': {'rank': 11, 'score': 0.11927572570999612}, 'Supreme Court spouse talks to Capitol riot investigators': {'rank': 36, 'score': 0.11091071398868566}, 'Rapper gives financial support to Bronx education institution': {'rank': 7, 'score': 0.15667348983894472}, 'Lawyers argue for life imprisonment for mass murderer': {'rank': 45, 'score': 0.08343759120461683}, 'New anchor takes over prime time slot on cable news': {'rank': 64, 'score': 0.05746337486394994}, 'Movie director discusses complex adult film industry character': {'rank': 960, 'score': 0.0}, 'Fatal accident involving college sports team students': {'rank': 1, 'score': 0.2850402079901924}}
# 22      (1, 2)       2     0.9          True   l2   141.750   0.118537      {'Violence on board during US flight': {'rank': 10, 'score': 0.13549555621392861}, 'Statistics regarding new virus vaccination fall campaign': {'rank': 11, 'score': 0.11927572570999612}, 'Supreme Court spouse talks to Capitol riot investigators': {'rank': 36, 'score': 0.11091071398868566}, 'Rapper gives financial support to Bronx education institution': {'rank': 7, 'score': 0.15667348983894472}, 'Lawyers argue for life imprisonment for mass murderer': {'rank': 45, 'score': 0.08343759120461683}, 'New anchor takes over prime time slot on cable news': {'rank': 64, 'score': 0.05746337486394994}, 'Movie director discusses complex adult film industry character': {'rank': 960, 'score': 0.0}, 'Fatal accident involving college sports team students': {'rank': 1, 'score': 0.2850402079901924}}
# 24      (1, 2)       3     0.8          True   l2   142.000   0.129049      {'Violence on board during US flight': {'rank': 11, 'score': 0.1476307094111076}, 'Statistics regarding new virus vaccination fall campaign': {'rank': 11, 'score': 0.13186222618553373}, 'Supreme Court spouse talks to Capitol riot investigators': {'rank': 34, 'score': 0.13820973589749602}, 'Rapper gives financial support to Bronx education institution': {'rank': 9, 'score': 0.19259617888597483}, 'Lawyers argue for life imprisonment for mass murderer': {'rank': 55, 'score': 0.08955198808071897}, 'New anchor takes over prime time slot on cable news': {'rank': 52, 'score': 0.07994512991097191}, 'Movie director discusses complex adult film industry character': {'rank': 961, 'score': 0.0}, 'Fatal accident involving college sports team students': {'rank': 3, 'score': 0.25259811900037404}}
# 26      (1, 2)       3     0.9          True   l2   142.000   0.129049      {'Violence on board during US flight': {'rank': 11, 'score': 0.1476307094111076}, 'Statistics regarding new virus vaccination fall campaign': {'rank': 11, 'score': 0.13186222618553373}, 'Supreme Court spouse talks to Capitol riot investigators': {'rank': 34, 'score': 0.13820973589749602}, 'Rapper gives financial support to Bronx education institution': {'rank': 9, 'score': 0.19259617888597483}, 'Lawyers argue for life imprisonment for mass murderer': {'rank': 55, 'score': 0.08955198808071897}, 'New anchor takes over prime time slot on cable news': {'rank': 52, 'score': 0.07994512991097191}, 'Movie director discusses complex adult film industry character': {'rank': 961, 'score': 0.0}, 'Fatal accident involving college sports team students': {'rank': 3, 'score': 0.25259811900037404}}
# 25      (1, 2)       3     0.8         False   l2   142.375   0.124552       {'Violence on board during US flight': {'rank': 11, 'score': 0.1476307094111076}, 'Statistics regarding new virus vaccination fall campaign': {'rank': 12, 'score': 0.1251345967880881}, 'Supreme Court spouse talks to Capitol riot investigators': {'rank': 37, 'score': 0.11914266009535097}, 'Rapper gives financial support to Bronx education institution': {'rank': 8, 'score': 0.18702960729795587}, 'Lawyers argue for life imprisonment for mass murderer': {'rank': 54, 'score': 0.08493210772175865}, 'New anchor takes over prime time slot on cable news': {'rank': 53, 'score': 0.07994512991097191}, 'Movie director discusses complex adult film industry character': {'rank': 961, 'score': 0.0}, 'Fatal accident involving college sports team students': {'rank': 3, 'score': 0.25259811900037404}}
# 27      (1, 2)       3     0.9         False   l2   142.375   0.124552       {'Violence on board during US flight': {'rank': 11, 'score': 0.1476307094111076}, 'Statistics regarding new virus vaccination fall campaign': {'rank': 12, 'score': 0.1251345967880881}, 'Supreme Court spouse talks to Capitol riot investigators': {'rank': 37, 'score': 0.11914266009535097}, 'Rapper gives financial support to Bronx education institution': {'rank': 8, 'score': 0.18702960729795587}, 'Lawyers argue for life imprisonment for mass murderer': {'rank': 54, 'score': 0.08493210772175865}, 'New anchor takes over prime time slot on cable news': {'rank': 53, 'score': 0.07994512991097191}, 'Movie director discusses complex adult film industry character': {'rank': 961, 'score': 0.0}, 'Fatal accident involving college sports team students': {'rank': 3, 'score': 0.25259811900037404}}
# 4       (1, 1)       2     0.8          True   l2   142.875   0.123856     {'Violence on board during US flight': {'rank': 10, 'score': 0.13978480569811327}, 'Statistics regarding new virus vaccination fall campaign': {'rank': 10, 'score': 0.13186222618553373}, 'Supreme Court spouse talks to Capitol riot investigators': {'rank': 44, 'score': 0.09714491648104895}, 'Rapper gives financial support to Bronx education institution': {'rank': 7, 'score': 0.15667348983894472}, 'Lawyers argue for life imprisonment for mass murderer': {'rank': 44, 'score': 0.09137658896872837}, 'New anchor takes over prime time slot on cable news': {'rank': 67, 'score': 0.06593066039067205}, 'Movie director discusses complex adult film industry character': {'rank': 960, 'score': 0.0}, 'Fatal accident involving college sports team students': {'rank': 1, 'score': 0.30807634475054946}}
# 6       (1, 1)       2     0.9          True   l2   142.875   0.123856     {'Violence on board during US flight': {'rank': 10, 'score': 0.13978480569811327}, 'Statistics regarding new virus vaccination fall campaign': {'rank': 10, 'score': 0.13186222618553373}, 'Supreme Court spouse talks to Capitol riot investigators': {'rank': 44, 'score': 0.09714491648104895}, 'Rapper gives financial support to Bronx education institution': {'rank': 7, 'score': 0.15667348983894472}, 'Lawyers argue for life imprisonment for mass murderer': {'rank': 44, 'score': 0.09137658896872837}, 'New anchor takes over prime time slot on cable news': {'rank': 67, 'score': 0.06593066039067205}, 'Movie director discusses complex adult film industry character': {'rank': 960, 'score': 0.0}, 'Fatal accident involving college sports team students': {'rank': 1, 'score': 0.30807634475054946}}
# 16      (1, 2)       1     0.8          True   l2   142.875   0.072381     {'Violence on board during US flight': {'rank': 13, 'score': 0.07560087886220361}, 'Statistics regarding new virus vaccination fall campaign': {'rank': 12, 'score': 0.05723143521559425}, 'Supreme Court spouse talks to Capitol riot investigators': {'rank': 34, 'score': 0.08141594836641523}, 'Rapper gives financial support to Bronx education institution': {'rank': 1, 'score': 0.12121789075131534}, 'Lawyers argue for life imprisonment for mass murderer': {'rank': 43, 'score': 0.0395734297114925}, 'New anchor takes over prime time slot on cable news': {'rank': 79, 'score': 0.023955737169111962}, 'Movie director discusses complex adult film industry character': {'rank': 960, 'score': 0.0}, 'Fatal accident involving college sports team students': {'rank': 1, 'score': 0.18004898511665918}}
# 18      (1, 2)       1     0.9          True   l2   142.875   0.072381     {'Violence on board during US flight': {'rank': 13, 'score': 0.07560087886220361}, 'Statistics regarding new virus vaccination fall campaign': {'rank': 12, 'score': 0.05723143521559425}, 'Supreme Court spouse talks to Capitol riot investigators': {'rank': 34, 'score': 0.08141594836641523}, 'Rapper gives financial support to Bronx education institution': {'rank': 1, 'score': 0.12121789075131534}, 'Lawyers argue for life imprisonment for mass murderer': {'rank': 43, 'score': 0.0395734297114925}, 'New anchor takes over prime time slot on cable news': {'rank': 79, 'score': 0.023955737169111962}, 'Movie director discusses complex adult film industry character': {'rank': 960, 'score': 0.0}, 'Fatal accident involving college sports team students': {'rank': 1, 'score': 0.18004898511665918}}
# 12      (1, 1)       5     0.8          True   l2   143.250   0.176095      {'Violence on board during US flight': {'rank': 9, 'score': 0.23132890286841426}, 'Statistics regarding new virus vaccination fall campaign': {'rank': 11, 'score': 0.18954643879981192}, 'Supreme Court spouse talks to Capitol riot investigators': {'rank': 38, 'score': 0.15442008838667343}, 'Rapper gives financial support to Bronx education institution': {'rank': 5, 'score': 0.25862309051365917}, 'Lawyers argue for life imprisonment for mass murderer': {'rank': 59, 'score': 0.09137658896872837}, 'New anchor takes over prime time slot on cable news': {'rank': 60, 'score': 0.11167377483939141}, 'Movie director discusses complex adult film industry character': {'rank': 961, 'score': 0.0}, 'Fatal accident involving college sports team students': {'rank': 3, 'score': 0.37179015473094784}}
# 14      (1, 1)       5     0.9          True   l2   143.250   0.176095      {'Violence on board during US flight': {'rank': 9, 'score': 0.23132890286841426}, 'Statistics regarding new virus vaccination fall campaign': {'rank': 11, 'score': 0.18954643879981192}, 'Supreme Court spouse talks to Capitol riot investigators': {'rank': 38, 'score': 0.15442008838667343}, 'Rapper gives financial support to Bronx education institution': {'rank': 5, 'score': 0.25862309051365917}, 'Lawyers argue for life imprisonment for mass murderer': {'rank': 59, 'score': 0.09137658896872837}, 'New anchor takes over prime time slot on cable news': {'rank': 60, 'score': 0.11167377483939141}, 'Movie director discusses complex adult film industry character': {'rank': 961, 'score': 0.0}, 'Fatal accident involving college sports team students': {'rank': 3, 'score': 0.37179015473094784}}
# 13      (1, 1)       5     0.8         False   l2   143.500   0.171636          {'Violence on board during US flight': {'rank': 9, 'score': 0.23132890286841426}, 'Statistics regarding new virus vaccination fall campaign': {'rank': 11, 'score': 0.185013592740212}, 'Supreme Court spouse talks to Capitol riot investigators': {'rank': 42, 'score': 0.1412085430791865}, 'Rapper gives financial support to Bronx education institution': {'rank': 5, 'score': 0.2455921702276022}, 'Lawyers argue for life imprisonment for mass murderer': {'rank': 58, 'score': 0.08648384152952938}, 'New anchor takes over prime time slot on cable news': {'rank': 59, 'score': 0.11167377483939141}, 'Movie director discusses complex adult film industry character': {'rank': 961, 'score': 0.0}, 'Fatal accident involving college sports team students': {'rank': 3, 'score': 0.37179015473094784}}
# 15      (1, 1)       5     0.9         False   l2   143.500   0.171636          {'Violence on board during US flight': {'rank': 9, 'score': 0.23132890286841426}, 'Statistics regarding new virus vaccination fall campaign': {'rank': 11, 'score': 0.185013592740212}, 'Supreme Court spouse talks to Capitol riot investigators': {'rank': 42, 'score': 0.1412085430791865}, 'Rapper gives financial support to Bronx education institution': {'rank': 5, 'score': 0.2455921702276022}, 'Lawyers argue for life imprisonment for mass murderer': {'rank': 58, 'score': 0.08648384152952938}, 'New anchor takes over prime time slot on cable news': {'rank': 59, 'score': 0.11167377483939141}, 'Movie director discusses complex adult film industry character': {'rank': 961, 'score': 0.0}, 'Fatal accident involving college sports team students': {'rank': 3, 'score': 0.37179015473094784}}
# 17      (1, 2)       1     0.8         False   l2   143.500   0.071221  {'Violence on board during US flight': {'rank': 12, 'score': 0.07560087886220361}, 'Statistics regarding new virus vaccination fall campaign': {'rank': 12, 'score': 0.056223215794882965}, 'Supreme Court spouse talks to Capitol riot investigators': {'rank': 35, 'score': 0.07505000449541963}, 'Rapper gives financial support to Bronx education institution': {'rank': 1, 'score': 0.12045313139173129}, 'Lawyers argue for life imprisonment for mass murderer': {'rank': 45, 'score': 0.038862835226682144}, 'New anchor takes over prime time slot on cable news': {'rank': 82, 'score': 0.023532457261427425}, 'Movie director discusses complex adult film industry character': {'rank': 960, 'score': 0.0}, 'Fatal accident involving college sports team students': {'rank': 1, 'score': 0.18004898511665918}}
# 19      (1, 2)       1     0.9         False   l2   143.500   0.071221  {'Violence on board during US flight': {'rank': 12, 'score': 0.07560087886220361}, 'Statistics regarding new virus vaccination fall campaign': {'rank': 12, 'score': 0.056223215794882965}, 'Supreme Court spouse talks to Capitol riot investigators': {'rank': 35, 'score': 0.07505000449541963}, 'Rapper gives financial support to Bronx education institution': {'rank': 1, 'score': 0.12045313139173129}, 'Lawyers argue for life imprisonment for mass murderer': {'rank': 45, 'score': 0.038862835226682144}, 'New anchor takes over prime time slot on cable news': {'rank': 82, 'score': 0.023532457261427425}, 'Movie director discusses complex adult film industry character': {'rank': 960, 'score': 0.0}, 'Fatal accident involving college sports team students': {'rank': 1, 'score': 0.18004898511665918}}
# 0       (1, 1)       1     0.8          True   l2   143.875   0.107565     {'Violence on board during US flight': {'rank': 12, 'score': 0.11525785740232222}, 'Statistics regarding new virus vaccination fall campaign': {'rank': 12, 'score': 0.08943826941664716}, 'Supreme Court spouse talks to Capitol riot investigators': {'rank': 40, 'score': 0.08953649769829371}, 'Rapper gives financial support to Bronx education institution': {'rank': 1, 'score': 0.18177908729200773}, 'Lawyers argue for life imprisonment for mass murderer': {'rank': 42, 'score': 0.06244082947766201}, 'New anchor takes over prime time slot on cable news': {'rank': 83, 'score': 0.043408341515897286}, 'Movie director discusses complex adult film industry character': {'rank': 960, 'score': 0.0}, 'Fatal accident involving college sports team students': {'rank': 1, 'score': 0.2786561399158394}}
# 2       (1, 1)       1     0.9          True   l2   143.875   0.107565     {'Violence on board during US flight': {'rank': 12, 'score': 0.11525785740232222}, 'Statistics regarding new virus vaccination fall campaign': {'rank': 12, 'score': 0.08943826941664716}, 'Supreme Court spouse talks to Capitol riot investigators': {'rank': 40, 'score': 0.08953649769829371}, 'Rapper gives financial support to Bronx education institution': {'rank': 1, 'score': 0.18177908729200773}, 'Lawyers argue for life imprisonment for mass murderer': {'rank': 42, 'score': 0.06244082947766201}, 'New anchor takes over prime time slot on cable news': {'rank': 83, 'score': 0.043408341515897286}, 'Movie director discusses complex adult film industry character': {'rank': 960, 'score': 0.0}, 'Fatal accident involving college sports team students': {'rank': 1, 'score': 0.2786561399158394}}
# 8       (1, 1)       3     0.8          True   l2   144.125   0.127750     {'Violence on board during US flight': {'rank': 11, 'score': 0.15322903242819325}, 'Statistics regarding new virus vaccination fall campaign': {'rank': 11, 'score': 0.13186222618553373}, 'Supreme Court spouse talks to Capitol riot investigators': {'rank': 45, 'score': 0.12039600358211522}, 'Rapper gives financial support to Bronx education institution': {'rank': 9, 'score': 0.19259617888597483}, 'Lawyers argue for life imprisonment for mass murderer': {'rank': 55, 'score': 0.09137658896872837}, 'New anchor takes over prime time slot on cable news': {'rank': 58, 'score': 0.07994512991097191}, 'Movie director discusses complex adult film industry character': {'rank': 961, 'score': 0.0}, 'Fatal accident involving college sports team students': {'rank': 3, 'score': 0.25259811900037404}}
# 10      (1, 1)       3     0.9          True   l2   144.125   0.127750     {'Violence on board during US flight': {'rank': 11, 'score': 0.15322903242819325}, 'Statistics regarding new virus vaccination fall campaign': {'rank': 11, 'score': 0.13186222618553373}, 'Supreme Court spouse talks to Capitol riot investigators': {'rank': 45, 'score': 0.12039600358211522}, 'Rapper gives financial support to Bronx education institution': {'rank': 9, 'score': 0.19259617888597483}, 'Lawyers argue for life imprisonment for mass murderer': {'rank': 55, 'score': 0.09137658896872837}, 'New anchor takes over prime time slot on cable news': {'rank': 58, 'score': 0.07994512991097191}, 'Movie director discusses complex adult film industry character': {'rank': 961, 'score': 0.0}, 'Fatal accident involving college sports team students': {'rank': 3, 'score': 0.25259811900037404}}
# 5       (1, 1)       2     0.8         False   l2   144.875   0.120020        {'Violence on board during US flight': {'rank': 9, 'score': 0.13978480569811327}, 'Statistics regarding new virus vaccination fall campaign': {'rank': 11, 'score': 0.1251345967880881}, 'Supreme Court spouse talks to Capitol riot investigators': {'rank': 58, 'score': 0.08260542429165903}, 'Rapper gives financial support to Bronx education institution': {'rank': 6, 'score': 0.1521451850606366}, 'Lawyers argue for life imprisonment for mass murderer': {'rank': 46, 'score': 0.08648384152952938}, 'New anchor takes over prime time slot on cable news': {'rank': 68, 'score': 0.06593066039067205}, 'Movie director discusses complex adult film industry character': {'rank': 960, 'score': 0.0}, 'Fatal accident involving college sports team students': {'rank': 1, 'score': 0.30807634475054946}}
# 7       (1, 1)       2     0.9         False   l2   144.875   0.120020        {'Violence on board during US flight': {'rank': 9, 'score': 0.13978480569811327}, 'Statistics regarding new virus vaccination fall campaign': {'rank': 11, 'score': 0.1251345967880881}, 'Supreme Court spouse talks to Capitol riot investigators': {'rank': 58, 'score': 0.08260542429165903}, 'Rapper gives financial support to Bronx education institution': {'rank': 6, 'score': 0.1521451850606366}, 'Lawyers argue for life imprisonment for mass murderer': {'rank': 46, 'score': 0.08648384152952938}, 'New anchor takes over prime time slot on cable news': {'rank': 68, 'score': 0.06593066039067205}, 'Movie director discusses complex adult film industry character': {'rank': 960, 'score': 0.0}, 'Fatal accident involving college sports team students': {'rank': 1, 'score': 0.30807634475054946}}
# 1       (1, 1)       1     0.8         False   l2   145.375   0.104773     {'Violence on board during US flight': {'rank': 12, 'score': 0.11525785740232222}, 'Statistics regarding new virus vaccination fall campaign': {'rank': 11, 'score': 0.08573030112804875}, 'Supreme Court spouse talks to Capitol riot investigators': {'rank': 49, 'score': 0.07777382406471489}, 'Rapper gives financial support to Bronx education institution': {'rank': 2, 'score': 0.17923007959311152}, 'Lawyers argue for life imprisonment for mass murderer': {'rank': 43, 'score': 0.05975608039581572}, 'New anchor takes over prime time slot on cable news': {'rank': 85, 'score': 0.041775726900037544}, 'Movie director discusses complex adult film industry character': {'rank': 960, 'score': 0.0}, 'Fatal accident involving college sports team students': {'rank': 1, 'score': 0.2786561399158394}}
# 3       (1, 1)       1     0.9         False   l2   145.375   0.104773     {'Violence on board during US flight': {'rank': 12, 'score': 0.11525785740232222}, 'Statistics regarding new virus vaccination fall campaign': {'rank': 11, 'score': 0.08573030112804875}, 'Supreme Court spouse talks to Capitol riot investigators': {'rank': 49, 'score': 0.07777382406471489}, 'Rapper gives financial support to Bronx education institution': {'rank': 2, 'score': 0.17923007959311152}, 'Lawyers argue for life imprisonment for mass murderer': {'rank': 43, 'score': 0.05975608039581572}, 'New anchor takes over prime time slot on cable news': {'rank': 85, 'score': 0.041775726900037544}, 'Movie director discusses complex adult film industry character': {'rank': 960, 'score': 0.0}, 'Fatal accident involving college sports team students': {'rank': 1, 'score': 0.2786561399158394}}
# 9       (1, 1)       3     0.8         False   l2   145.750   0.123146      {'Violence on board during US flight': {'rank': 11, 'score': 0.15322903242819325}, 'Statistics regarding new virus vaccination fall campaign': {'rank': 14, 'score': 0.1251345967880881}, 'Supreme Court spouse talks to Capitol riot investigators': {'rank': 56, 'score': 0.10074933596297826}, 'Rapper gives financial support to Bronx education institution': {'rank': 8, 'score': 0.18702960729795587}, 'Lawyers argue for life imprisonment for mass murderer': {'rank': 53, 'score': 0.08648384152952938}, 'New anchor takes over prime time slot on cable news': {'rank': 60, 'score': 0.07994512991097191}, 'Movie director discusses complex adult film industry character': {'rank': 961, 'score': 0.0}, 'Fatal accident involving college sports team students': {'rank': 3, 'score': 0.25259811900037404}}
# 11      (1, 1)       3     0.9         False   l2   145.750   0.123146      {'Violence on board during US flight': {'rank': 11, 'score': 0.15322903242819325}, 'Statistics regarding new virus vaccination fall campaign': {'rank': 14, 'score': 0.1251345967880881}, 'Supreme Court spouse talks to Capitol riot investigators': {'rank': 56, 'score': 0.10074933596297826}, 'Rapper gives financial support to Bronx education institution': {'rank': 8, 'score': 0.18702960729795587}, 'Lawyers argue for life imprisonment for mass murderer': {'rank': 53, 'score': 0.08648384152952938}, 'New anchor takes over prime time slot on cable news': {'rank': 60, 'score': 0.07994512991097191}, 'Movie director discusses complex adult film industry character': {'rank': 961, 'score': 0.0}, 'Fatal accident involving college sports team students': {'rank': 3, 'score': 0.25259811900037404}}
# 45      (2, 2)       5     0.8         False   l2   386.000   0.074513                                                                                                 {'Violence on board during US flight': {'rank': 54, 'score': 0.0}, 'Statistics regarding new virus vaccination fall campaign': {'rank': 42, 'score': 0.0}, 'Supreme Court spouse talks to Capitol riot investigators': {'rank': 6, 'score': 0.5961045117894112}, 'Rapper gives financial support to Bronx education institution': {'rank': 862, 'score': 0.0}, 'Lawyers argue for life imprisonment for mass murderer': {'rank': 510, 'score': 0.0}, 'New anchor takes over prime time slot on cable news': {'rank': 210, 'score': 0.0}, 'Movie director discusses complex adult film industry character': {'rank': 961, 'score': 0.0}, 'Fatal accident involving college sports team students': {'rank': 443, 'score': 0.0}}
# 47      (2, 2)       5     0.9         False   l2   386.000   0.074513                                                                                                 {'Violence on board during US flight': {'rank': 54, 'score': 0.0}, 'Statistics regarding new virus vaccination fall campaign': {'rank': 42, 'score': 0.0}, 'Supreme Court spouse talks to Capitol riot investigators': {'rank': 6, 'score': 0.5961045117894112}, 'Rapper gives financial support to Bronx education institution': {'rank': 862, 'score': 0.0}, 'Lawyers argue for life imprisonment for mass murderer': {'rank': 510, 'score': 0.0}, 'New anchor takes over prime time slot on cable news': {'rank': 210, 'score': 0.0}, 'Movie director discusses complex adult film industry character': {'rank': 961, 'score': 0.0}, 'Fatal accident involving college sports team students': {'rank': 443, 'score': 0.0}}
# 44      (2, 2)       5     0.8          True   l2   386.125   0.074513                                                                                                 {'Violence on board during US flight': {'rank': 54, 'score': 0.0}, 'Statistics regarding new virus vaccination fall campaign': {'rank': 42, 'score': 0.0}, 'Supreme Court spouse talks to Capitol riot investigators': {'rank': 7, 'score': 0.5961045117894112}, 'Rapper gives financial support to Bronx education institution': {'rank': 862, 'score': 0.0}, 'Lawyers argue for life imprisonment for mass murderer': {'rank': 510, 'score': 0.0}, 'New anchor takes over prime time slot on cable news': {'rank': 210, 'score': 0.0}, 'Movie director discusses complex adult film industry character': {'rank': 961, 'score': 0.0}, 'Fatal accident involving college sports team students': {'rank': 443, 'score': 0.0}}
# 46      (2, 2)       5     0.9          True   l2   386.125   0.074513                                                                                                 {'Violence on board during US flight': {'rank': 54, 'score': 0.0}, 'Statistics regarding new virus vaccination fall campaign': {'rank': 42, 'score': 0.0}, 'Supreme Court spouse talks to Capitol riot investigators': {'rank': 7, 'score': 0.5961045117894112}, 'Rapper gives financial support to Bronx education institution': {'rank': 862, 'score': 0.0}, 'Lawyers argue for life imprisonment for mass murderer': {'rank': 510, 'score': 0.0}, 'New anchor takes over prime time slot on cable news': {'rank': 210, 'score': 0.0}, 'Movie director discusses complex adult film industry character': {'rank': 961, 'score': 0.0}, 'Fatal accident involving college sports team students': {'rank': 443, 'score': 0.0}}
# 32      (2, 2)       1     0.8          True   l2   388.750   0.009747                                                                                               {'Violence on board during US flight': {'rank': 54, 'score': 0.0}, 'Statistics regarding new virus vaccination fall campaign': {'rank': 42, 'score': 0.0}, 'Supreme Court spouse talks to Capitol riot investigators': {'rank': 29, 'score': 0.07797976982757986}, 'Rapper gives financial support to Bronx education institution': {'rank': 862, 'score': 0.0}, 'Lawyers argue for life imprisonment for mass murderer': {'rank': 510, 'score': 0.0}, 'New anchor takes over prime time slot on cable news': {'rank': 209, 'score': 0.0}, 'Movie director discusses complex adult film industry character': {'rank': 961, 'score': 0.0}, 'Fatal accident involving college sports team students': {'rank': 443, 'score': 0.0}}
# 34      (2, 2)       1     0.9          True   l2   388.750   0.009747                                                                                               {'Violence on board during US flight': {'rank': 54, 'score': 0.0}, 'Statistics regarding new virus vaccination fall campaign': {'rank': 42, 'score': 0.0}, 'Supreme Court spouse talks to Capitol riot investigators': {'rank': 29, 'score': 0.07797976982757986}, 'Rapper gives financial support to Bronx education institution': {'rank': 862, 'score': 0.0}, 'Lawyers argue for life imprisonment for mass murderer': {'rank': 510, 'score': 0.0}, 'New anchor takes over prime time slot on cable news': {'rank': 209, 'score': 0.0}, 'Movie director discusses complex adult film industry character': {'rank': 961, 'score': 0.0}, 'Fatal accident involving college sports team students': {'rank': 443, 'score': 0.0}}
# 40      (2, 2)       3     0.8          True   l2   389.000   0.024685                                                                                               {'Violence on board during US flight': {'rank': 54, 'score': 0.0}, 'Statistics regarding new virus vaccination fall campaign': {'rank': 42, 'score': 0.0}, 'Supreme Court spouse talks to Capitol riot investigators': {'rank': 30, 'score': 0.19747651566282906}, 'Rapper gives financial support to Bronx education institution': {'rank': 862, 'score': 0.0}, 'Lawyers argue for life imprisonment for mass murderer': {'rank': 510, 'score': 0.0}, 'New anchor takes over prime time slot on cable news': {'rank': 210, 'score': 0.0}, 'Movie director discusses complex adult film industry character': {'rank': 961, 'score': 0.0}, 'Fatal accident involving college sports team students': {'rank': 443, 'score': 0.0}}
# 41      (2, 2)       3     0.8         False   l2   389.000   0.024685                                                                                               {'Violence on board during US flight': {'rank': 54, 'score': 0.0}, 'Statistics regarding new virus vaccination fall campaign': {'rank': 42, 'score': 0.0}, 'Supreme Court spouse talks to Capitol riot investigators': {'rank': 30, 'score': 0.19747651566282906}, 'Rapper gives financial support to Bronx education institution': {'rank': 862, 'score': 0.0}, 'Lawyers argue for life imprisonment for mass murderer': {'rank': 510, 'score': 0.0}, 'New anchor takes over prime time slot on cable news': {'rank': 210, 'score': 0.0}, 'Movie director discusses complex adult film industry character': {'rank': 961, 'score': 0.0}, 'Fatal accident involving college sports team students': {'rank': 443, 'score': 0.0}}
# 42      (2, 2)       3     0.9          True   l2   389.000   0.024685                                                                                               {'Violence on board during US flight': {'rank': 54, 'score': 0.0}, 'Statistics regarding new virus vaccination fall campaign': {'rank': 42, 'score': 0.0}, 'Supreme Court spouse talks to Capitol riot investigators': {'rank': 30, 'score': 0.19747651566282906}, 'Rapper gives financial support to Bronx education institution': {'rank': 862, 'score': 0.0}, 'Lawyers argue for life imprisonment for mass murderer': {'rank': 510, 'score': 0.0}, 'New anchor takes over prime time slot on cable news': {'rank': 210, 'score': 0.0}, 'Movie director discusses complex adult film industry character': {'rank': 961, 'score': 0.0}, 'Fatal accident involving college sports team students': {'rank': 443, 'score': 0.0}}
# 43      (2, 2)       3     0.9         False   l2   389.000   0.024685                                                                                               {'Violence on board during US flight': {'rank': 54, 'score': 0.0}, 'Statistics regarding new virus vaccination fall campaign': {'rank': 42, 'score': 0.0}, 'Supreme Court spouse talks to Capitol riot investigators': {'rank': 30, 'score': 0.19747651566282906}, 'Rapper gives financial support to Bronx education institution': {'rank': 862, 'score': 0.0}, 'Lawyers argue for life imprisonment for mass murderer': {'rank': 510, 'score': 0.0}, 'New anchor takes over prime time slot on cable news': {'rank': 210, 'score': 0.0}, 'Movie director discusses complex adult film industry character': {'rank': 961, 'score': 0.0}, 'Fatal accident involving college sports team students': {'rank': 443, 'score': 0.0}}
# 37      (2, 2)       2     0.8         False   l2   389.000   0.018712                                                                                               {'Violence on board during US flight': {'rank': 54, 'score': 0.0}, 'Statistics regarding new virus vaccination fall campaign': {'rank': 42, 'score': 0.0}, 'Supreme Court spouse talks to Capitol riot investigators': {'rank': 31, 'score': 0.14969210108145942}, 'Rapper gives financial support to Bronx education institution': {'rank': 862, 'score': 0.0}, 'Lawyers argue for life imprisonment for mass murderer': {'rank': 510, 'score': 0.0}, 'New anchor takes over prime time slot on cable news': {'rank': 209, 'score': 0.0}, 'Movie director discusses complex adult film industry character': {'rank': 961, 'score': 0.0}, 'Fatal accident involving college sports team students': {'rank': 443, 'score': 0.0}}
# 39      (2, 2)       2     0.9         False   l2   389.000   0.018712                                                                                               {'Violence on board during US flight': {'rank': 54, 'score': 0.0}, 'Statistics regarding new virus vaccination fall campaign': {'rank': 42, 'score': 0.0}, 'Supreme Court spouse talks to Capitol riot investigators': {'rank': 31, 'score': 0.14969210108145942}, 'Rapper gives financial support to Bronx education institution': {'rank': 862, 'score': 0.0}, 'Lawyers argue for life imprisonment for mass murderer': {'rank': 510, 'score': 0.0}, 'New anchor takes over prime time slot on cable news': {'rank': 209, 'score': 0.0}, 'Movie director discusses complex adult film industry character': {'rank': 961, 'score': 0.0}, 'Fatal accident involving college sports team students': {'rank': 443, 'score': 0.0}}
# 36      (2, 2)       2     0.8          True   l2   389.125   0.018712                                                                                               {'Violence on board during US flight': {'rank': 54, 'score': 0.0}, 'Statistics regarding new virus vaccination fall campaign': {'rank': 42, 'score': 0.0}, 'Supreme Court spouse talks to Capitol riot investigators': {'rank': 32, 'score': 0.14969210108145942}, 'Rapper gives financial support to Bronx education institution': {'rank': 862, 'score': 0.0}, 'Lawyers argue for life imprisonment for mass murderer': {'rank': 510, 'score': 0.0}, 'New anchor takes over prime time slot on cable news': {'rank': 209, 'score': 0.0}, 'Movie director discusses complex adult film industry character': {'rank': 961, 'score': 0.0}, 'Fatal accident involving college sports team students': {'rank': 443, 'score': 0.0}}
# 38      (2, 2)       2     0.9          True   l2   389.125   0.018712                                                                                               {'Violence on board during US flight': {'rank': 54, 'score': 0.0}, 'Statistics regarding new virus vaccination fall campaign': {'rank': 42, 'score': 0.0}, 'Supreme Court spouse talks to Capitol riot investigators': {'rank': 32, 'score': 0.14969210108145942}, 'Rapper gives financial support to Bronx education institution': {'rank': 862, 'score': 0.0}, 'Lawyers argue for life imprisonment for mass murderer': {'rank': 510, 'score': 0.0}, 'New anchor takes over prime time slot on cable news': {'rank': 209, 'score': 0.0}, 'Movie director discusses complex adult film industry character': {'rank': 961, 'score': 0.0}, 'Fatal accident involving college sports team students': {'rank': 443, 'score': 0.0}}
# 33      (2, 2)       1     0.8         False   l2   389.250   0.009517                                                                                               {'Violence on board during US flight': {'rank': 54, 'score': 0.0}, 'Statistics regarding new virus vaccination fall campaign': {'rank': 42, 'score': 0.0}, 'Supreme Court spouse talks to Capitol riot investigators': {'rank': 33, 'score': 0.07613834489844601}, 'Rapper gives financial support to Bronx education institution': {'rank': 862, 'score': 0.0}, 'Lawyers argue for life imprisonment for mass murderer': {'rank': 510, 'score': 0.0}, 'New anchor takes over prime time slot on cable news': {'rank': 209, 'score': 0.0}, 'Movie director discusses complex adult film industry character': {'rank': 961, 'score': 0.0}, 'Fatal accident involving college sports team students': {'rank': 443, 'score': 0.0}}
# 35      (2, 2)       1     0.9         False   l2   389.250   0.009517                                                                                               {'Violence on board during US flight': {'rank': 54, 'score': 0.0}, 'Statistics regarding new virus vaccination fall campaign': {'rank': 42, 'score': 0.0}, 'Supreme Court spouse talks to Capitol riot investigators': {'rank': 33, 'score': 0.07613834489844601}, 'Rapper gives financial support to Bronx education institution': {'rank': 862, 'score': 0.0}, 'Lawyers argue for life imprisonment for mass murderer': {'rank': 510, 'score': 0.0}, 'New anchor takes over prime time slot on cable news': {'rank': 209, 'score': 0.0}, 'Movie director discusses complex adult film industry character': {'rank': 961, 'score': 0.0}, 'Fatal accident involving college sports team students': {'rank': 443, 'score': 0.0}}

# %%
best_row = tfidf_df.iloc[0]

best_row['all_results']
# Out:
# {'Violence on board during US flight': {'rank': 9,
#   'score': np.float64(0.21996089551565737)},
#  'Statistics regarding new virus vaccination fall campaign': {'rank': 11,
#   'score': np.float64(0.18954643879981192)},
#  'Supreme Court spouse talks to Capitol riot investigators': {'rank': 28,
#   'score': np.float64(0.19314707622584368)},
#  'Rapper gives financial support to Bronx education institution': {'rank': 5,
#   'score': np.float64(0.25862309051365917)},
#  'Lawyers argue for life imprisonment for mass murderer': {'rank': 59,
#   'score': np.float64(0.08955198808071897)},
#  'New anchor takes over prime time slot on cable news': {'rank': 53,
#   'score': np.float64(0.11167377483939141)},
#  'Movie director discusses complex adult film industry character': {'rank': 961,
#   'score': np.float64(0.0)},
#  'Fatal accident involving college sports team students': {'rank': 3,
#   'score': np.float64(0.37179015473094784)}}

# %% [markdown]
# ## 3. Eksperymenty z Doc2Vec

# %%
def run_doc2vec_experiment_batch(docs, golden_set, model_params):
    tagged_docs = [TaggedDocument(doc.content.split(), [doc.name]) for doc in docs]
    doc_names = [d.name for d in docs]

    # Trenujemy model RAZ dla danego zestawu parametrów
    model = Doc2Vec(tagged_docs, **model_params)
    
    results = {}
    for query, expected_doc_name in golden_set.items():
        query_tokens = DocumentService.preprocess_text(query, return_tokens=True)
        # Zwiększamy jakość inferencji (epochs zamiast steps dla starszych wersji gensim)
        # Dodajemy seed dla powtarzalności
        query_vector = model.infer_vector(query_tokens, epochs=100)
        
        try:
            # Pobieramy podobieństwa dla wszystkich dokumentów
            sims = model.dv.most_similar([query_vector], topn=len(docs))
            sim_names = [name for name, _ in sims]
            
            rank = sim_names.index(expected_doc_name) + 1
            score = next(s for name, s in sims if name == expected_doc_name)
            
            results[query] = {'rank': rank, 'score': score}
        except (ValueError, KeyError):
            results[query] = {'rank': -1, 'score': -1}
            
    return results

# Rozszerzona siatka parametrów dla Doc2Vec
doc2vec_param_grid = {
    'vector_size': [200, 300],
    'window': [5, 10],
    'min_count': [1, 2],
    'epochs': [100, 200],
    'dm': [0, 1],
    'alpha': [0.025, 0.05],
    'dbow_words': [1]
}

doc2vec_results = []
params_list_d2v = list(itertools.product(*doc2vec_param_grid.values()))

for params in tqdm(params_list_d2v, desc="Doc2Vec Experiments"):
    current_params = dict(zip(doc2vec_param_grid.keys(), params))
    
    # Przebieg batchowy dla wszystkich zapytań
    query_results = run_doc2vec_experiment_batch(documents, GOLDEN_SET, current_params)
    
    ranks = [res['rank'] for res in query_results.values() if res['rank'] != -1]
    scores = [res['score'] for res in query_results.values() if res['score'] != -1]
    
    if ranks:
        avg_rank = sum(ranks) / len(ranks)
        avg_score = sum(scores) / len(scores)
        result_entry = {**current_params, 'avg_rank': avg_rank, 'avg_score': avg_score, 'all_results': query_results}
        doc2vec_results.append(result_entry)

doc2vec_df = pd.DataFrame(doc2vec_results)
doc2vec_df.sort_values(by=['avg_rank', 'avg_score'], ascending=[True, False], inplace=True)

print("Najlepsze parametry dla Doc2Vec (Summary)")
# Usuwamy all_results z widoku, żeby tabela była czytelna
display(doc2vec_df.drop(columns=['all_results']).head(100))
# Out:
# Doc2Vec Experiments:   2%|▏         | 1/64 [00:04<05:09,  4.92s/it]Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# Doc2Vec Experiments:   3%|▎         | 2/64 [00:09<04:52,  4.72s/it]Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# Doc2Vec Experiments:   6%|▋         | 4/64 [00:13<02:51,  2.86s/it]Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# Doc2Vec Experiments:   8%|▊         | 5/64 [00:22<04:58,  5.06s/it]Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# Doc2Vec Experiments:  20%|██        | 13/64 [00:56<03:40,  4.33s/it]Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# Doc2Vec Experiments:  25%|██▌       | 16/64 [01:10<03:25,  4.28s/it]Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# Doc2Vec Experiments:  27%|██▋       | 17/64 [01:17<03:57,  5.05s/it]Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# Doc2Vec Experiments:  33%|███▎      | 21/64 [01:40<04:34,  6.38s/it]Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# Doc2Vec Experiments:  38%|███▊      | 24/64 [02:00<04:00,  6.00s/it]Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# Doc2Vec Experiments:  45%|████▌     | 29/64 [02:25<03:19,  5.70s/it]Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# Doc2Vec Experiments:  52%|█████▏    | 33/64 [02:49<02:52,  5.57s/it]Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# Doc2Vec Experiments:  62%|██████▎   | 40/64 [03:29<02:17,  5.73s/it]Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# Doc2Vec Experiments:  66%|██████▌   | 42/64 [03:38<01:55,  5.23s/it]Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# Doc2Vec Experiments:  69%|██████▉   | 44/64 [03:42<01:11,  3.56s/it]Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# Doc2Vec Experiments:  70%|███████   | 45/64 [03:51<01:38,  5.19s/it]Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# Doc2Vec Experiments:  75%|███████▌  | 48/64 [04:07<01:19,  4.96s/it]Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# Doc2Vec Experiments:  78%|███████▊  | 50/64 [04:25<01:34,  6.74s/it]Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# Doc2Vec Experiments:  80%|███████▉  | 51/64 [04:27<01:11,  5.48s/it]Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# Doc2Vec Experiments:  83%|████████▎ | 53/64 [04:45<01:27,  7.97s/it]Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# Doc2Vec Experiments:  94%|█████████▍| 60/64 [05:28<00:18,  4.57s/it]Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# Doc2Vec Experiments: 100%|██████████| 64/64 [06:02<00:00,  5.66s/it]
# Najlepsze parametry dla Doc2Vec (Summary)
#     vector_size  window  min_count  epochs  dm  alpha  dbow_words  avg_rank  avg_score
# 9           200       5          2     100   0  0.050           1    19.750   0.489195
# 12          200       5          2     200   0  0.025           1    23.125   0.492849
# 45          300       5          2     200   0  0.050           1    25.000   0.469414
# 41          300       5          2     100   0  0.050           1    28.875   0.470040
# 13          200       5          2     200   0  0.050           1    28.875   0.459404
# 8           200       5          2     100   0  0.025           1    29.500   0.506306
# 44          300       5          2     200   0  0.025           1    35.875   0.486903
# 29          200      10          2     200   0  0.050           1    37.125   0.477147
# 61          300      10          2     200   0  0.050           1    46.125   0.461959
# 28          200      10          2     200   0  0.025           1    48.375   0.488038
# 6           200       5          1     200   1  0.025           1    50.750   0.068571
# 25          200      10          2     100   0  0.050           1    51.000   0.471621
# 40          300       5          2     100   0  0.025           1    51.750   0.496641
# 3           200       5          1     100   1  0.050           1    52.250   0.167682
# 60          300      10          2     200   0  0.025           1    52.375   0.491145
# 24          200      10          2     100   0  0.025           1    54.750   0.509209
# 42          300       5          2     100   1  0.025           1    54.875   0.399418
# 38          300       5          1     200   1  0.025           1    54.875   0.110461
# 2           200       5          1     100   1  0.025           1    56.625   0.400815
# 21          200      10          1     200   0  0.050           1    58.625   0.452068
# 57          300      10          2     100   0  0.050           1    58.750   0.467746
# 20          200      10          1     200   0  0.025           1    61.375   0.473465
# 10          200       5          2     100   1  0.025           1    63.875   0.372054
# 35          300       5          1     100   1  0.050           1    68.500   0.170823
# 34          300       5          1     100   1  0.025           1    71.500   0.376234
# 56          300      10          2     100   0  0.025           1    73.250   0.492737
# 43          300       5          2     100   1  0.050           1    73.875   0.205074
# 58          300      10          2     100   1  0.025           1    77.000   0.310253
# 17          200      10          1     100   0  0.050           1    78.250   0.454157
# 11          200       5          2     100   1  0.050           1    80.125   0.212761
# 4           200       5          1     200   0  0.025           1    80.250   0.467076
# 36          300       5          1     200   0  0.025           1    80.375   0.468969
# 16          200      10          1     100   0  0.025           1    81.625   0.484342
# 5           200       5          1     200   0  0.050           1    82.750   0.444490
# 0           200       5          1     100   0  0.025           1    82.875   0.489159
# 32          300       5          1     100   0  0.025           1    83.375   0.490265
# 46          300       5          2     200   1  0.025           1    83.875   0.152139
# 26          200      10          2     100   1  0.025           1    84.125   0.314624
# 22          200      10          1     200   1  0.025           1    86.250  -0.026149
# 52          300      10          1     200   0  0.025           1    87.000   0.458486
# 54          300      10          1     200   1  0.025           1    87.375  -0.037956
# 33          300       5          1     100   0  0.050           1    91.875   0.445050
# 53          300      10          1     200   0  0.050           1    94.625   0.425023
# 7           200       5          1     200   1  0.050           1    95.250   0.100652
# 48          300      10          1     100   0  0.025           1    95.500   0.478458
# 1           200       5          1     100   0  0.050           1    95.500   0.446863
# 14          200       5          2     200   1  0.025           1    99.250   0.134232
# 49          300      10          1     100   0  0.050           1   109.125   0.441388
# 37          300       5          1     200   0  0.050           1   110.500   0.429716
# 19          200      10          1     100   1  0.050           1   113.750   0.072098
# 18          200      10          1     100   1  0.025           1   115.500   0.231381
# 15          200       5          2     200   1  0.050           1   115.625   0.160958
# 30          200      10          2     200   1  0.025           1   119.250   0.047662
# 50          300      10          1     100   1  0.025           1   119.500   0.246254
# 51          300      10          1     100   1  0.050           1   122.375   0.044238
# 62          300      10          2     200   1  0.025           1   144.750   0.039546
# 39          300       5          1     200   1  0.050           1   155.000   0.118525
# 27          200      10          2     100   1  0.050           1   156.875   0.155320
# 59          300      10          2     100   1  0.050           1   157.875   0.130392
# 55          300      10          1     200   1  0.050           1   172.000  -0.006123
# 47          300       5          2     200   1  0.050           1   192.750   0.160907
# 23          200      10          1     200   1  0.050           1   216.750  -0.007724
# 31          200      10          2     200   1  0.050           1   237.000   0.114292
# 63          300      10          2     200   1  0.050           1   239.500   0.103445
